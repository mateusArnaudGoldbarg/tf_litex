# %% [markdown]
# # Train a Simple TensorFlow Lite for Microcontrollers model
#
# This notebook demonstrates the process of training a 2.5 kB model using TensorFlow and converting it for use with TensorFlow Lite for Microcontrollers.
#
# Deep learning networks learn to model patterns in underlying data. Here, we're going to train a network to model data generated by a [sine](https://en.wikipedia.org/wiki/Sine) function. This will result in a model that can take a value, `x`, and predict its sine, `y`.
#
# The model created in this notebook is used in the [hello_world](https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world) example for [TensorFlow Lite for MicroControllers](https://www.tensorflow.org/lite/microcontrollers/overview).
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world/train/train_hello_world_model.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world/train/train_hello_world_model.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# ## Configure Defaults

# %%
# Define paths to model files
import os
MODELS_DIR = 'models/'
if not os.path.exists(MODELS_DIR):
    os.mkdir(MODELS_DIR)
MODEL_TF = MODELS_DIR + 'model.keras'
MODEL_NO_QUANT_TFLITE = MODELS_DIR + 'model_no_quant.tflite'
MODEL_TFLITE = MODELS_DIR + 'model.tflite'
MODEL_TFLITE_MICRO = MODELS_DIR + 'model.cc'

# %% [markdown]
# ## Setup Environment
#
# Install Dependencies

# %% [markdown]
# Import Dependencies

# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf

# Keras is TensorFlow's high-level API for deep learning
from tensorflow import keras
# Numpy is a math library
import numpy as np
# Pandas is a data manipulation library
import pandas as pd
# Matplotlib is a graphing library
import matplotlib.pyplot as plt
# Math is Python's math library
import math

print(tf.__version__)

# Set seed for experiment reproducibility
seed = 1
np.random.seed(seed)
tf.random.set_seed(seed)
# Out:
# 2.19.0

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### 1. Generate Data
#
# The code in the following cell will generate a set of random `x` values, calculate their sine values, and display them on a graph.

# %%
# Number of sample datapoints
SAMPLES = 1000

# Generate a uniformly distributed set of random numbers in the range from
# 0 to 2π, which covers a complete sine wave oscillation
x_values = np.random.uniform(
    low=0, high=2*math.pi, size=SAMPLES).astype(np.float32)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

# Calculate the corresponding sine values
y_values = np.sin(x_values).astype(np.float32)

# Plot our data. The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ### 2. Add Noise
# Since it was generated directly by the sine function, our data fits a nice, smooth curve.
#
# However, machine learning models are good at extracting underlying meaning from messy, real world data. To demonstrate this, we can add some noise to our data to approximate something more life-like.
#
# In the following cell, we'll add some random noise to each value, then draw a new graph:

# %%
# Add a small random number to each y value
y_values += 0.1 * np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ### 3. Split the Data
# We now have a noisy dataset that approximates real world data. We'll be using this to train our model.
#
# To evaluate the accuracy of the model we train, we'll need to compare its predictions to real data and check how well they match up. This evaluation happens during training (where it is referred to as validation) and after training (referred to as testing) It's important in both cases that we use fresh data that was not already used to train the model.
#
# The data is split as follows:
#   1. Training: 60%
#   2. Validation: 20%
#   3. Testing: 20%
#
# The following code will split our data and then plots each set as a different color:

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Training

# %% [markdown]
# ### 1. Design the Model
# We're going to build a simple neural network model that will take an input value (in this case, `x`) and use it to predict a numeric output value (the sine of `x`). This type of problem is called a _regression_. It will use _layers_ of _neurons_ to attempt to learn any patterns underlying the training data, so it can make predictions.
#
# To begin with, we'll define two layers. The first layer takes a single input (our `x` value) and runs it through 8 neurons. Based on this input, each neuron will become _activated_ to a certain degree based on its internal state (its _weight_ and _bias_ values). A neuron's degree of activation is expressed as a number.
#
# The activation numbers from our first layer will be fed as inputs to our second layer, which is a single neuron. It will apply its own weights and bias to these inputs and calculate its own activation, which will be output as our `y` value.
#
# **Note:** To learn more about how neural networks function, you can explore the [Learn TensorFlow](https://codelabs.developers.google.com/codelabs/tensorflow-lab1-helloworld) codelabs.
#
# The code in the following cell defines our model using [Keras](https://www.tensorflow.org/guide/keras), TensorFlow's high-level API for creating deep learning networks. Once the network is defined, we _compile_ it, specifying parameters that determine how it will be trained:

# %%
# We'll use Keras to create a simple model architecture
model_1 = tf.keras.Sequential([
    # Add Input layer first (Keras 3 best practice)
    keras.layers.Input(shape=(1,)),

    # First layer takes a scalar input and feeds it through 8 "neurons". The
    # neurons decide whether to activate based on the 'relu' activation function.
    keras.layers.Dense(8, activation='relu'),

    # Final layer is a single neuron, since we want to output a single value
    keras.layers.Dense(1)
])

# Compile the model using the standard 'adam' optimizer and the mean squared error or 'mse' loss function for regression.
model_1.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# ### 2. Train the Model
# Once we've defined the model, we can use our data to _train_ it. Training involves passing an `x` value into the neural network, checking how far the network's output deviates from the expected `y` value, and adjusting the neurons' weights and biases so that the output is more likely to be correct the next time.
#
# Training runs this process on the full dataset multiple times, and each full run-through is known as an _epoch_. The number of epochs to run during training is a parameter we can set.
#
# During each epoch, data is run through the network in multiple _batches_. Each batch, several pieces of data are passed into the network, producing output values. These outputs' correctness is measured in aggregate and the network's weights and biases are adjusted accordingly, once per batch. The _batch size_ is also a parameter we can set.
#
# The code in the following cell uses the `x` and `y` values from our training data to train the model. It runs for 500 _epochs_, with 64 pieces of data in each _batch_. We also pass in some data for _validation_. As you will see when you run the cell, training can take a while to complete:

# %%
# Train the model on our training data while validating on our validation set
history_1 = model_1.fit(x_train, y_train, epochs=250, batch_size=64,
                        validation_data=(x_validate, y_validate))
# Out:
# Epoch 1/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.5716 - mae: 0.6106 - val_loss: 0.5250 - val_mae: 0.5881
# Epoch 2/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5138 - mae: 0.5789 - val_loss: 0.4812 - val_mae: 0.5702
# Epoch 3/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4712 - mae: 0.5576 - val_loss: 0.4512 - val_mae: 0.5591
# Epoch 4/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4419 - mae: 0.5447 - val_loss: 0.4311 - val_mae: 0.5530
# Epoch 5/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4219 - mae: 0.5360 - val_loss: 0.4177 - val_mae: 0.5487
# Epoch 6/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4083 - mae: 0.5305 - val_loss: 0.4086 - val_mae: 0.5466
# Epoch 7/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3989 - mae: 0.5280 - val_loss: 0.4023 - val_mae: 0.5448
# Epoch 8/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3922 - mae: 0.5270 - val_loss: 0.3977 - val_mae: 0.5431
# Epoch 9/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3873 - mae: 0.5263 - val_loss: 0.3941 - val_mae: 0.5418
# Epoch 10/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3833 - mae: 0.5256 - val_loss: 0.3910 - val_mae: 0.5406
# Epoch 11/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3799 - mae: 0.5248 - val_loss: 0.3880 - val_mae: 0.5393
# Epoch 12/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3766 - mae: 0.5237 - val_loss: 0.3850 - val_mae: 0.5379
# Epoch 13/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3734 - mae: 0.5222 - val_loss: 0.3819 - val_mae: 0.5362
# Epoch 14/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3702 - mae: 0.5203 - val_loss: 0.3787 - val_mae: 0.5343
# Epoch 15/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3670 - mae: 0.5183 - val_loss: 0.3754 - val_mae: 0.5322
# Epoch 16/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3636 - mae: 0.5160 - val_loss: 0.3720 - val_mae: 0.5300
# Epoch 17/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3603 - mae: 0.5136 - val_loss: 0.3686 - val_mae: 0.5277
# Epoch 18/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3569 - mae: 0.5111 - val_loss: 0.3651 - val_mae: 0.5253
# Epoch 19/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3534 - mae: 0.5085 - val_loss: 0.3615 - val_mae: 0.5229
# Epoch 20/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3499 - mae: 0.5059 - val_loss: 0.3579 - val_mae: 0.5205
# Epoch 21/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3464 - mae: 0.5033 - val_loss: 0.3543 - val_mae: 0.5181
# Epoch 22/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3429 - mae: 0.5007 - val_loss: 0.3507 - val_mae: 0.5156
# Epoch 23/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3393 - mae: 0.4980 - val_loss: 0.3471 - val_mae: 0.5131
# Epoch 24/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3358 - mae: 0.4955 - val_loss: 0.3435 - val_mae: 0.5107
# Epoch 25/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.
250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2288 - mae: 0.4162 - val_loss: 0.2371 - val_mae: 0.4323
# Epoch 60/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2266 - mae: 0.4145 - val_loss: 0.2350 - val_mae: 0.4306
# Epoch 61/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2246 - mae: 0.4128 - val_loss: 0.2330 - val_mae: 0.4289
# Epoch 62/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2226 - mae: 0.4111 - val_loss: 0.2311 - val_mae: 0.4272
# Epoch 63/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2206 - mae: 0.4095 - val_loss: 0.2292 - val_mae: 0.4255
# Epoch 64/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2187 - mae: 0.4079 - val_loss: 0.2274 - val_mae: 0.4239
# Epoch 65/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2169 - mae: 0.4063 - val_loss: 0.2256 - val_mae: 0.4223
# Epoch 66/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2151 - mae: 0.4047 - val_loss: 0.2239 - val_mae: 0.4207
# Epoch 67/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2134 - mae: 0.4032 - val_loss: 0.2223 - val_mae: 0.4193
# Epoch 68/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2117 - mae: 0.4018 - val_loss: 0.2207 - val_mae: 0.4178
# Epoch 69/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2101 - mae: 0.4003 - val_loss: 0.2191 - val_mae: 0.4164
# Epoch 70/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2085 - mae: 0.3989 - val_loss: 0.2177 - val_mae: 0.4149
# Epoch 71/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2070 - mae: 0.3976 - val_loss: 0.2162 - val_mae: 0.4136
# Epoch 72/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2056 - mae: 0.3963 - val_loss: 0.2149 - val_mae: 0.4123
# Epoch 73/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2042 - mae: 0.3950 - val_loss: 0.2136 - val_mae: 0.4110
# Epoch 74/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2028 - mae: 0.3937 - val_loss: 0.2123 - val_mae: 0.4099
# Epoch 75/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2016 - mae: 0.3925 - val_loss: 0.2111 - val_mae: 0.4087
# Epoch 76/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2003 - mae: 0.3913 - val_loss: 0.2100 - val_mae: 0.4075
# Epoch 77/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1991 - mae: 0.3901 - val_loss: 0.2088 - val_mae: 0.4064
# Epoch 78/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1980 - mae: 0.3890 - val_loss: 0.2078 - val_mae: 0.4053
# Epoch 79/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1969 - mae: 0.3879 - val_loss: 0.2067 - val_mae: 0.4042
# Epoch 80/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1958 - mae: 0.3868 - val_loss: 0.2057 - val_mae: 0.4031
# Epoch 81/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1948 - mae: 0.3858 - val_loss: 0.2048 - val_mae: 0.4021
# Epoch 82/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1938 - mae: 0.3848 - val_loss: 0.2039 - val_mae: 0.4012
# Epoch 83/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1929 - mae: 0.3838 - val_loss: 0.2030 - val_mae: 0.4003
# Epoch 84/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1920 - mae: 0.3829 - val_loss: 0.2022 - val_mae: 0.3994
# Epoch 85/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1911 - mae: 0.3819 - val_loss: 0.2014 - val_mae: 0.3985
# Epoch 86/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1903 - mae: 0.3810 - val_loss: 0.2006 - val_mae: 0.3977
# Epoch 87/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1895 - mae: 0.3802 - val_loss: 0.1999 - val_mae: 0.3969
# Epoch 88/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1887 - mae: 0.3793 - val_loss: 0.1991 - val_mae: 0.3961
# Epoch 89/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1880 - mae: 0.3785 - val_loss: 0.1985 - val_mae: 0.3953
# Epoch 90/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1873 - mae: 0.3777 - val_loss: 0.1978 - val_mae: 0.3945
# Epoch 91/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1866 - mae: 0.3769 - val_loss: 0.1972 - val_mae: 0.3937
# Epoch 92/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1859 - mae: 0.3762 - val_loss: 0.1966 - val_mae: 0.3930
# Epoch 93/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1853 - mae: 0.3755 - val_loss: 0.1960 - val_mae: 0.3923
# Epoch 94/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1847 - mae: 0.3748 - val_loss: 0.1955 - val_mae: 0.3917
# Epoch 95/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1841 - mae: 0.3741 - val_loss: 0.1950 - val_mae: 0.3910
# Epoch 96/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1836 - mae: 0.3735 - val_loss: 0.1945 - val_mae: 0.3903
# Epoch 97/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1831 - mae: 0.3728 - val_loss: 0.1941 - val_mae: 0.3897
# Epoch 98/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1826 - mae: 0.3722 - val_loss: 0.1936 - val_mae: 0.3891
# Epoch 99/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1821 - mae: 0.3716 - val_loss: 0.1932 - val_mae: 0.3885
# Epoch 100/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1817 - mae: 0.3711 - val_loss: 0.1928 - val_mae: 0.3880
# Epoch 101/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1813 - mae: 0.3705 - val_loss: 0.1924 - val_mae: 0.3874
# Epoch 102/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1809 - mae: 0.3700 - val_loss: 0.1921 - val_mae: 0.3869
# Epoch 103/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1805 - mae: 0.3694 - val_loss: 0.1918 - val_mae: 0.3864
# Epoch 104/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1801 - mae: 0.3689 - val_loss: 0.1914 - val_mae: 0.3859
# Epoch 105/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1798 - mae: 0.3684 - val_loss: 0.1911 - val_mae: 0.3854
# Epoch 106/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1794 - mae: 0.3679 - val_loss: 0.1908 - val_mae: 0.3849
# Epoch 107/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1791 - mae: 0.3674 - val_loss: 0.1905 - val_mae: 0.3845
# Epoch 108/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1788 - mae: 0.3670 - val_loss: 0.1903 - val_mae: 0.3840
# Epoch 109/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1785 - mae: 0.3665 - val_loss: 0.1900 - val_mae: 0.3836
# Epoch 110/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1783 - mae: 0.3661 - val_loss: 0.1898 - val_mae: 0.3832
# Epoch 111/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1780 - mae: 0.3657 - val_loss: 0.1896 - val_mae: 0.3828
# Epoch 112/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1778 - mae: 0.3653 - val_loss: 0.1894 - val_mae: 0.3824
# Epoch 113/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1775 - mae: 0.3649 - val_loss: 0.1892 - val_mae: 0.3820
# Epoch 114/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1773 - mae: 0.3645 - val_loss: 0.1890 - val_mae: 0.3817
# Epoch 115/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1771 - mae: 0.3641 - val_loss: 0.1888 - val_mae: 0.3813
# Epoch 116/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1769 - mae: 0.3638 - val_loss: 0.1886 - val_mae: 0.3810
# Epoch 117/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1767 - mae: 0.3634 - val_loss: 0.1885 - val_mae: 0.3807
# Epoch 118/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1765 - mae: 0.3631 - val_loss: 0.1883 - val_mae: 0.3804
# Epoch 119/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1763 - mae: 0.3628 - val_loss: 0.1882 - val_mae: 0.3801
# Epoch 120/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1762 - mae: 0.3625 - val_loss: 0.1880 - val_mae: 0.3799
# Epoch 121/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1760 - mae: 0.3621 - val_loss: 0.1879 - val_mae: 0.3796
# Epoch 122/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1759 - mae: 0.3619 - val_loss: 0.1878 - val_mae: 0.3793
# Epoch 123/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1757 - mae: 0.3616 - val_loss: 0.1876 - val_mae: 0.3791
# Epoch 124/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1756 - mae: 0.3613 - val_loss: 0.1875 - val_mae: 0.3788
# Epoch 125/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1755 - mae: 0.3610 - val_loss: 0.1874 - val_mae: 0.3786
# Epoch 126/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1754 - mae: 0.3608 - val_loss: 0.1873 - val_mae: 0.3784
# Epoch 127/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1752 - mae: 0.3606 - val_loss: 0.1872 - val_mae: 0.3782
# Epoch 128/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1751 - mae: 0.3603 - val_loss: 0.1872 - val_mae: 0.3780
# Epoch 129/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1750 - mae: 0.3601 - val_loss: 0.1871 - val_mae: 0.3778
# Epoch 130/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1749 - mae: 0.3599 - val_loss: 0.1870 - val_mae: 0.3776
# Epoch 131/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1749 - mae: 0.3597 - val_loss: 0.1869 - val_mae: 0.3774
# Epoch 132/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1748 - mae: 0.3595 - val_loss: 0.1868 - val_mae: 0.3772
# Epoch 133/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1747 - mae: 0.3593 - val_loss: 0.1868 - val_mae: 0.3770
# Epoch 134/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1746 - mae: 0.3592 - val_loss: 0.1867 - val_mae: 0.3768
# Epoch 135/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1745 - mae: 0.3590 - val_loss: 0.1866 - val_mae: 0.3766
# Epoch 136/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1745 - mae: 0.3588 - val_loss: 0.1866 - val_mae: 0.3765
# Epoch 137/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1744 - mae: 0.3587 - val_loss: 0.1865 - val_mae: 0.3763
# Epoch 138/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1744 - mae: 0.3585 - val_loss: 0.1865 - val_mae: 0.3762
# Epoch 139/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1743 - mae: 0.3584 - val_loss: 0.1864 - val_mae: 0.3760
# Epoch 140/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1742 - mae: 0.3582 - val_loss: 0.1864 - val_mae: 0.3759
# Epoch 141/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1742 - mae: 0.3581 - val_loss: 0.1863 - val_mae: 0.3757
# Epoch 142/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1741 - mae: 0.3580 - val_loss: 0.1863 - val_mae: 0.3756
# Epoch 143/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1741 - mae: 0.3578 - val_loss: 0.1862 - val_mae: 0.3755
# Epoch 144/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1740 - mae: 0.3577 - val_loss: 0.1862 - val_mae: 0.3754
# Epoch 145/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1740 - mae: 0.3576 - val_loss: 0.1861 - val_mae: 0.3752
# Epoch 146/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1740 - mae: 0.3575 - val_loss: 0.1861 - val_mae: 0.3751
# Epoch 147/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1739 - mae: 0.3574 - val_loss: 0.1861 - val_mae: 0.3750
# Epoch 148/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1739 - mae: 0.3573 - val_loss: 0.1860 - val_mae: 0.3749
# Epoch 149/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1738 - mae: 0.3572 - val_loss: 0.1860 - val_mae: 0.3748
# Epoch 150/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1738 - mae: 0.3571 - val_loss: 0.1860 - val_mae: 0.3747
# Epoch 151/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1738 - mae: 0.3570 - val_loss: 0.1859 - val_mae: 0.3746
# Epoch 152/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1737 - mae: 0.3569 - val_loss: 0.1859 - val_mae: 0.3745
# Epoch 153/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1737 - mae: 0.3568 - val_loss: 0.1859 - val_mae: 0.3744
# Epoch 154/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1737 - mae: 0.3567 - val_loss: 0.1858 - val_mae: 0.3743
# Epoch 155/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1737 - mae: 0.3567 - val_loss: 0.1858 - val_mae: 0.3742
# Epoch 156/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1736 - mae: 0.3566 - val_loss: 0.1858 - val_mae: 0.3741
# Epoch 157/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1736 - mae: 0.3565 - val_loss: 0.1858 - val_mae: 0.3741
# Epoch 158/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1736 - mae: 0.3565 - val_loss: 0.1857 - val_mae: 0.3740
# Epoch 159/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1736 - mae: 0.3564 - val_loss: 0.1857 - val_mae: 0.3739
# Epoch 160/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1735 - mae: 0.3563 - val_loss: 0.1857 - val_mae: 0.3738
# Epoch 161/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1735 - mae: 0.3563 - val_loss: 0.1857 - val_mae: 0.3737
# Epoch 162/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1735 - mae: 0.3562 - val_loss: 0.1857 - val_mae: 0.3737
# Epoch 163/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1735 - mae: 0.3562 - val_loss: 0.1856 - val_mae: 0.3736
# Epoch 164/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1735 - mae: 0.3561 - val_loss: 0.1856 - val_mae: 0.3735
# Epoch 165/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1735 - mae: 0.3560 - val_loss: 0.1856 - val_mae: 0.3735
# Epoch 166/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1735 - mae: 0.3560 - val_loss: 0.1856 - val_mae: 0.3734
# Epoch 167/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1734 - mae: 0.3560 - val_loss: 0.1856 - val_mae: 0.3734
# Epoch 168/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1734 - mae: 0.3559 - val_loss: 0.1855 - val_mae: 0.3733
# Epoch 169/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1734 - mae: 0.3559 - val_loss: 0.1855 - val_mae: 0.3732
# Epoch 170/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1734 - mae: 0.3558 - val_loss: 0.1855 - val_mae: 0.3732
# Epoch 171/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1734 - mae: 0.3558 - val_loss: 0.1855 - val_mae: 0.3732
# Epoch 172/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1734 - mae: 0.3557 - val_loss: 0.1855 - val_mae: 0.3731
# Epoch 173/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1734 - mae: 0.3557 - val_loss: 0.1855 - val_mae: 0.3731
# Epoch 174/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1734 - mae: 0.3557 - val_loss: 0.1855 - val_mae: 0.3730
# Epoch 175/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1734 - mae: 0.3556 - val_loss: 0.1855 - val_mae: 0.3730
# Epoch 176/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1734 - mae: 0.3556 - val_loss: 0.1855 - val_mae: 0.3729
# Epoch 177/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1733 - mae: 0.3556 - val_loss: 0.1854 - val_mae: 0.3729
# Epoch 178/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1733 - mae: 0.3555 - val_loss: 0.1854 - val_mae: 0.3729
# Epoch 179/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1733 - mae: 0.3555 - val_loss: 0.1854 - val_mae: 0.3728
# Epoch 180/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1733 - mae: 0.3555 - val_loss: 0.1854 - val_mae: 0.3728
# Epoch 181/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1733 - mae: 0.3555 - val_loss: 0.1854 - val_mae: 0.3727
# Epoch 182/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1733 - mae: 0.3554 - val_loss: 0.1854 - val_mae: 0.3727
# Epoch 183/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1733 - mae: 0.3554 - val_loss: 0.1854 - val_mae: 0.3727
# Epoch 184/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1733 - mae: 0.3554 - val_loss: 0.1854 - val_mae: 0.3727
# Epoch 185/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1733 - mae: 0.3554 - val_loss: 0.1854 - val_mae: 0.3726
# Epoch 186/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1733 - mae: 0.3553 - val_loss: 0.1854 - val_mae: 0.3726
# Epoch 187/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1733 - mae: 0.3553 - val_loss: 0.1854 - val_mae: 0.3726
# Epoch 188/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1733 - mae: 0.3553 - val_loss: 0.1854 - val_mae: 0.3725
# Epoch 189/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1733 - mae: 0.3553 - val_loss: 0.1854 - val_mae: 0.3725
# Epoch 190/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1733 - mae: 0.3553 - val_loss: 0.1854 - val_mae: 0.3725
# Epoch 191/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1733 - mae: 0.3552 - val_loss: 0.1854 - val_mae: 0.3725
# Epoch 192/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1733 - mae: 0.3552 - val_loss: 0.1854 - val_mae: 0.3724
# Epoch 193/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1733 - mae: 0.3552 - val_loss: 0.1854 - val_mae: 0.3724
# Epoch 194/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.
250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1732 - mae: 0.3549 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 228/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1732 - mae: 0.3549 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 229/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1732 - mae: 0.3549 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 230/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1732 - mae: 0.3549 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 231/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1732 - mae: 0.3549 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 232/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 233/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 234/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 235/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 236/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 237/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 238/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 239/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 240/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 241/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 242/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 243/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 244/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 245/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 246/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 247/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3719
# Epoch 248/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3718
# Epoch 249/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3718
# Epoch 250/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1732 - mae: 0.3548 - val_loss: 0.1852 - val_mae: 0.3718

# %% [markdown]
# ### 3. Plot Metrics

# %% [markdown]
# **1. Loss (or Mean Squared Error)**
#
# During training, the model's performance is constantly being measured against both our training data and the validation data that we set aside earlier. Training produces a log of data that tells us how the model's performance changed over the course of the training process.
#
# The following cells will display some of that data in a graphical form:

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
train_loss = history_1.history['loss']
val_loss = history_1.history['val_loss']

epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# The graph shows the _loss_ (or the difference between the model's predictions and the actual data) for each epoch. There are several ways to calculate loss, and the method we have used is _mean squared error_. There is a distinct loss value given for the training and the validation data.
#
# As we can see, the amount of loss rapidly decreases over the first 25 epochs, before flattening out. This means that the model is improving and producing more accurate predictions!
#
# Our goal is to stop training when either the model is no longer improving, or when the _training loss_ is less than the _validation loss_, which would mean that the model has learned to predict the training data so well that it can no longer generalize to new data.
#
# To make the flatter part of the graph more readable, let's skip the first 50 epochs:

# %%
# Exclude the first few epochs so the graph is easier to read
SKIP = 50

plt.plot(epochs[SKIP:], train_loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# From the plot, we can see that loss continues to reduce until around 200 epochs, at which point it is mostly stable. This means that there's no need to train our network beyond 200 epochs.
#
# However, we can also see that the lowest loss value is still around 0.155. This means that our network's predictions are off by an average of ~15%. In addition, the validation loss values jump around a lot, and is sometimes even higher.
#
# **2. Mean Absolute Error**
#
# To gain more insight into our model's performance we can plot some more data. This time, we'll plot the _mean absolute error_, which is another way of measuring how far the network's predictions are from the actual numbers:

# %%
plt.clf()

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
train_mae = history_1.history['mae']
val_mae = history_1.history['val_mae']

plt.plot(epochs[SKIP:], train_mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# This graph of _mean absolute error_ tells another story. We can see that training data shows consistently lower error than validation data, which means that the network may have _overfit_, or learned the training data so rigidly that it can't make effective predictions about new data.
#
# In addition, the mean absolute error values are quite high, ~0.305 at best, which means some of the model's predictions are at least 30% off. A 30% error means we are very far from accurately modelling the sine wave function.
#
# **3. Actual vs Predicted Outputs**
#
# To get more insight into what is happening, let's check its predictions against the test dataset we set aside earlier:

# %%
# Calculate and print the loss on our test dataset
test_loss, test_mae = model_1.evaluate(x_test, y_test)

# Make predictions based on our test dataset
y_test_pred = model_1.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual values')
plt.plot(x_test, y_test_pred, 'r.', label='TF predictions')
plt.legend()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1558 - mae: 0.3371
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# Oh dear! The graph makes it clear that our network has learned to approximate the sine function in a very limited way.
#
# The rigidity of this fit suggests that the model does not have enough capacity to learn the full complexity of the sine wave function, so it's only able to approximate it in an overly simplistic way. By making our model bigger, we should be able to improve its performance.

# %% [markdown]
# ## Training a Larger Model

# %% [markdown]
# ### 1. Design the Model
# To make our model bigger, let's add an additional layer of neurons. The following cell redefines our model in the same way as earlier, but with 16 neurons in the first layer and an additional layer of 16 neurons in the middle:

# %%
model = tf.keras.Sequential([
    # Add Input layer first (Keras 3 best practice)
    keras.layers.Input(shape=(1,)),

    # First layer takes a scalar input and feeds it through 16 "neurons". The
    # neurons decide whether to activate based on the 'relu' activation function.
    keras.layers.Dense(16, activation='relu'),

    # The new second and third layer will help the network learn more complex representations
    keras.layers.Dense(16, activation='relu'),

    # Final layer is a single neuron, since we want to output a single value
    keras.layers.Dense(1)
])

# Compile the model using the standard 'adam' optimizer and the mean squared error or 'mse' loss function for regression.
model.compile(optimizer='adam', loss="mse", metrics=["mae"])

# %% [markdown]
# ### 2. Train the Model ###
#
# We'll now train and save the new model.

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=250, batch_size=64,
                    validation_data=(x_validate, y_validate))

# Save the model to disk
model.save(MODEL_TF)
print(MODEL_TF)
# Out:
# Epoch 1/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.4849 - mae: 0.5660 - val_loss: 0.4454 - val_mae: 0.5628
# Epoch 2/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4325 - mae: 0.5450 - val_loss: 0.4262 - val_mae: 0.5602
# Epoch 3/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4143 - mae: 0.5444 - val_loss: 0.4174 - val_mae: 0.5584
# Epoch 4/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4048 - mae: 0.5461 - val_loss: 0.4120 - val_mae: 0.5570
# Epoch 5/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3977 - mae: 0.5434 - val_loss: 0.4019 - val_mae: 0.5495
# Epoch 6/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3868 - mae: 0.5340 - val_loss: 0.3842 - val_mae: 0.5371
# Epoch 7/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3669 - mae: 0.5199 - val_loss: 0.3631 - val_mae: 0.5261
# Epoch 8/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3483 - mae: 0.5094 - val_loss: 0.3462 - val_mae: 0.5135
# Epoch 9/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3316 - mae: 0.4945 - val_loss: 0.3285 - val_mae: 0.4993
# Epoch 10/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3156 - mae: 0.4799 - val_loss: 0.3118 - val_mae: 0.4864
# Epoch 11/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2999 - mae: 0.4674 - val_loss: 0.2961 - val_mae: 0.4751
# Epoch 12/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2851 - mae: 0.4572 - val_loss: 0.2818 - val_mae: 0.4657
# Epoch 13/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2706 - mae: 0.4467 - val_loss: 0.2674 - val_mae: 0.4548
# Epoch 14/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2568 - mae: 0.4359 - val_loss: 0.2538 - val_mae: 0.4441
# Epoch 15/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2435 - mae: 0.4250 - val_loss: 0.2406 - val_mae: 0.4327
# Epoch 16/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2309 - mae: 0.4145 - val_loss: 0.2282 - val_mae: 0.4219
# Epoch 17/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2189 - mae: 0.4042 - val_loss: 0.2163 - val_mae: 0.4110
# Epoch 18/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2076 - mae: 0.3944 - val_loss: 0.2055 - val_mae: 0.4011
# Epoch 19/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1970 - mae: 0.3848 - val_loss: 0.1952 - val_mae: 0.3917
# Epoch 20/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1871 - mae: 0.3757 - val_loss: 0.1858 - val_mae: 0.3827
# Epoch 21/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1781 - mae: 0.3670 - val_loss: 0.1772 - val_mae: 0.3740
# Epoch 22/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1697 - mae: 0.3583 - val_loss: 0.1692 - val_mae: 0.3652
# Epoch 23/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1621 - mae: 0.3500 - val_loss: 0.1621 - val_mae: 0.3569
# Epoch 24/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1550 - mae: 0.3418 - val_loss: 0.1557 - val_mae: 0.3490
# Epoch 25/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1485 - mae: 0.3339 - val_loss: 0.1499 - val_mae: 0.3414
# Epoch 26/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1426 - mae: 0.3264 - val_loss: 0.1448 - val_mae: 0.3344
# Epoch 27/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1372 - mae: 0.3190 - val_loss: 0.1400 - val_mae: 0.3271
# Epoch 28/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1321 - mae: 0.3119 - val_loss: 0.1356 - val_mae: 0.3202
# Epoch 29/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1275 - mae: 0.3053 - val_loss: 0.1319 - val_mae: 0.3139
# Epoch 30/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1234 - mae: 0.2987 - val_loss: 0.1284 - val_mae: 0.3077
# Epoch 31/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1196 - mae: 0.2925 - val_loss: 0.1253 - val_mae: 0.3016
# Epoch 32/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1162 - mae: 0.2865 - val_loss: 0.1225 - val_mae: 0.2959
# Epoch 33/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1130 - mae: 0.2809 - val_loss: 0.1199 - val_mae: 0.2906
# Epoch 34/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1102 - mae: 0.2756 - val_loss: 0.1174 - val_mae: 0.2855
# Epoch 35/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1076 - mae: 0.2707 - val_loss: 0.1153 - val_mae: 0.2810
# Epoch 36/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1052 - mae: 0.2659 - val_loss: 0.1133 - val_mae: 0.2765
# Epoch 37/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1029 - mae: 0.2613 - val_loss: 0.1114 - val_mae: 0.2721
# Epoch 38/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1009 - mae: 0.2569 - val_loss: 0.1098 - val_mae: 0.2681
# Epoch 39/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0990 - mae: 0.2527 - val_loss: 0.1082 - val_mae: 0.2641
# Epoch 40/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0973 - mae: 0.2487 - val_loss: 0.1069 - val_mae: 0.2605
# Epoch 41/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0958 - mae: 0.2449 - val_loss: 0.1056 - val_mae: 0.2572
# Epoch 42/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0944 - mae: 0.2414 - val_loss: 0.1044 - val_mae: 0.2540
# Epoch 43/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0931 - mae: 0.2384 - val_loss: 0.1034 - val_mae: 0.2515
# Epoch 44/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0919 - mae: 0.2355 - val_loss: 0.1025 - val_mae: 0.2492
# Epoch 45/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0908 - mae: 0.2330 - val_loss: 0.1016 - val_mae: 0.2469
# Epoch 46/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0898 - mae: 0.2308 - val_loss: 0.1007 - val_mae: 0.2448
# Epoch 47/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0889 - mae: 0.2289 - val_loss: 0.1000 - val_mae: 0.2430
# Epoch 48/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0881 - mae: 0.2270 - val_loss: 0.0993 - val_mae: 0.2414
# Epoch 49/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0873 - mae: 0.2254 - val_loss: 0.0986 - val_mae: 0.2400
# Epoch 50/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0866 - mae: 0.2238 - val_loss: 0.0980 - val_mae: 0.2387
# Epoch 51/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0859 - mae: 0.2224 - val_loss: 0.0974 - val_mae: 0.2374
# Epoch 52/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0853 - mae: 0.2211 - val_loss: 0.0968 - val_mae: 0.2363
# Epoch 53/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0847 - mae: 0.2198 - val_loss: 0.0963 - val_mae: 0.2353
# Epoch 54/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0841 - mae: 0.2186 - val_loss: 0.0958 - val_mae: 0.2342
# Epoch 55/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0836 - mae: 0.2175 - val_loss: 0.0953 - val_mae: 0.2332
# Epoch 56/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0830 - mae: 0.2164 - val_loss: 0.0948 - val_mae: 0.2323
# Epoch 57/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0825 - mae: 0.2154 - val_loss: 0.0943 - val_mae: 0.2314
# Epoch 58/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0820 - mae: 0.2144 - val_loss: 0.0939 - val_mae: 0.2304
# Epoch 59/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0815 - mae: 0.2135 - val_loss: 0.0934 - val_mae: 0.2295
# Epoch 60/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0811 - mae: 0.2127 - val_loss: 0.0929 - val_mae: 0.2287
# Epoch 61/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0806 - mae: 0.2118 - val_loss: 0.0925 - val_mae: 0.2279
# Epoch 62/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0802 - mae: 0.2110 - val_loss: 0.0920 - val_mae: 0.2269
# Epoch 63/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0797 - mae: 0.2101 - val_loss: 0.0916 - val_mae: 0.2260
# Epoch 64/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0793 - mae: 0.2093 - val_loss: 0.0911 - val_mae: 0.2251
# Epoch 65/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0789 - mae: 0.2084 - val_loss: 0.0907 - val_mae: 0.2241
# Epoch 66/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0785 - mae: 0.2077 - val_loss: 0.0902 - val_mae: 0.2233
# Epoch 67/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0780 - mae: 0.2068 - val_loss: 0.0898 - val_mae: 0.2223
# Epoch 68/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0776 - mae: 0.2060 - val_loss: 0.0894 - val_mae: 0.2215
# Epoch 69/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0772 - mae: 0.2053 - val_loss: 0.0889 - val_mae: 0.2207
# Epoch 70/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0768 - mae: 0.2045 - val_loss: 0.0885 - val_mae: 0.2199
# Epoch 71/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0765 - mae: 0.2038 - val_loss: 0.0881 - val_mae: 0.2192
# Epoch 72/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0761 - mae: 0.2031 - val_loss: 0.0877 - val_mae: 0.2184
# Epoch 73/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0757 - mae: 0.2024 - val_loss: 0.0873 - val_mae: 0.2177
# Epoch 74/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0753 - mae: 0.2017 - val_loss: 0.0868 - val_mae: 0.2170
# Epoch 75/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0750 - mae: 0.2011 - val_loss: 0.0864 - val_mae: 0.2163
# Epoch 76/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0746 - mae: 0.2004 - val_loss: 0.0860 - val_mae: 0.2156
# Epoch 77/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0742 - mae: 0.1997 - val_loss: 0.0856 - val_mae: 0.2149
# Epoch 78/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0739 - mae: 0.1990 - val_loss: 0.0852 - val_mae: 0.2142
# Epoch 79/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0735 - mae: 0.1984 - val_loss: 0.0848 - val_mae: 0.2135
# Epoch 80/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0732 - mae: 0.1978 - val_loss: 0.0844 - val_mae: 0.2128
# Epoch 81/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0728 - mae: 0.1972 - val_loss: 0.0840 - val_mae: 0.2122
# Epoch 82/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0725 - mae: 0.1966 - val_loss: 0.0837 - val_mae: 0.2115
# Epoch 83/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0721 - mae: 0.1959 - val_loss: 0.0833 - val_mae: 0.2108
# Epoch 84/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0718 - mae: 0.1953 - val_loss: 0.0829 - val_mae: 0.2102
# Epoch 85/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0714 - mae: 0.1947 - val_loss: 0.0825 - val_mae: 0.2095
# Epoch 86/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0711 - mae: 0.1940 - val_loss: 0.0822 - val_mae: 0.2089
# Epoch 87/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0708 - mae: 0.1934 - val_loss: 0.0818 - val_mae: 0.2083
# Epoch 88/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0704 - mae: 0.1928 - val_loss: 0.0814 - val_mae: 0.2077
# Epoch 89/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0701 - mae: 0.1921 - val_loss: 0.0811 - val_mae: 0.2071
# Epoch 90/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0697 - mae: 0.1915 - val_loss: 0.0807 - val_mae: 0.2065
# Epoch 91/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0694 - mae: 0.1908 - val_loss: 0.0804 - val_mae: 0.2059
# Epoch 92/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0691 - mae: 0.1903 - val_loss: 0.0800 - val_mae: 0.2054
# Epoch 93/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0688 - mae: 0.1897 - val_loss: 0.0797 - val_mae: 0.2049
# Epoch 94/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0685 - mae: 0.1892 - val_loss: 0.0793 - val_mae: 0.2044
# Epoch 95/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0681 - mae: 0.1886 - val_loss: 0.0790 - val_mae: 0.2039
# Epoch 96/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0678 - mae: 0.1881 - val_loss: 0.0786 - val_mae: 0.2033
# Epoch 97/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0675 - mae: 0.1876 - val_loss: 0.0783 - val_mae: 0.2028
# Epoch 98/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0672 - mae: 0.1871 - val_loss: 0.0780 - val_mae: 0.2023
# Epoch 99/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0669 - mae: 0.1866 - val_loss: 0.0776 - val_mae: 0.2018
# Epoch 100/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0666 - mae: 0.1860 - val_loss: 0.0773 - val_mae: 0.2014
# Epoch 101/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0663 - mae: 0.1856 - val_loss: 0.0770 - val_mae: 0.2009
# Epoch 102/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0660 - mae: 0.1850 - val_loss: 0.0766 - val_mae: 0.2004
# Epoch 103/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0658 - mae: 0.1846 - val_loss: 0.0763 - val_mae: 0.1999
# Epoch 104/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0655 - mae: 0.1841 - val_loss: 0.0760 - val_mae: 0.1994
# Epoch 105/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0652 - mae: 0.1836 - val_loss: 0.0757 - val_mae: 0.1989
# Epoch 106/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0649 - mae: 0.1830 - val_loss: 0.0754 - val_mae: 0.1984
# Epoch 107/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0646 - mae: 0.1825 - val_loss: 0.0750 - val_mae: 0.1979
# Epoch 108/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0643 - mae: 0.1820 - val_loss: 0.0747 - val_mae: 0.1974
# Epoch 109/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0641 - mae: 0.1815 - val_loss: 0.0744 - val_mae: 0.1970
# Epoch 110/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0638 - mae: 0.1811 - val_loss: 0.0741 - val_mae: 0.1966
# Epoch 111/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0635 - mae: 0.1807 - val_loss: 0.0738 - val_mae: 0.1961
# Epoch 112/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0632 - mae: 0.1802 - val_loss: 0.0735 - val_mae: 0.1957
# Epoch 113/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0630 - mae: 0.1798 - val_loss: 0.0732 - val_mae: 0.1953
# Epoch 114/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0627 - mae: 0.1793 - val_loss: 0.0729 - val_mae: 0.1948
# Epoch 115/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0624 - mae: 0.1789 - val_loss: 0.0726 - val_mae: 0.1944
# Epoch 116/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0622 - mae: 0.1784 - val_loss: 0.0723 - val_mae: 0.1940
# Epoch 117/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0619 - mae: 0.1780 - val_loss: 0.0720 - val_mae: 0.1936
# Epoch 118/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0617 - mae: 0.1775 - val_loss: 0.0717 - val_mae: 0.1932
# Epoch 119/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0614 - mae: 0.1771 - val_loss: 0.0714 - val_mae: 0.1928
# Epoch 120/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0612 - mae: 0.1767 - val_loss: 0.0711 - val_mae: 0.1924
# Epoch 121/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0609 - mae: 0.1762 - val_loss: 0.0708 - val_mae: 0.1920
# Epoch 122/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0606 - mae: 0.1758 - val_loss: 0.0705 - val_mae: 0.1916
# Epoch 123/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0604 - mae: 0.1754 - val_loss: 0.0702 - val_mae: 0.1912
# Epoch 124/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0601 - mae: 0.1750 - val_loss: 0.0699 - val_mae: 0.1909
# Epoch 125/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0599 - mae: 0.1746 - val_loss: 0.0697 - val_mae: 0.1905
# Epoch 126/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0596 - mae: 0.1742 - val_loss: 0.0694 - val_mae: 0.1902
# Epoch 127/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0594 - mae: 0.1738 - val_loss: 0.0691 - val_mae: 0.1898
# Epoch 128/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0591 - mae: 0.1733 - val_loss: 0.0688 - val_mae: 0.1895
# Epoch 129/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0589 - mae: 0.1729 - val_loss: 0.0685 - val_mae: 0.1891
# Epoch 130/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0586 - mae: 0.1725 - val_loss: 0.0682 - val_mae: 0.1888
# Epoch 131/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0584 - mae: 0.1721 - val_loss: 0.0680 - val_mae: 0.1884
# Epoch 132/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0582 - mae: 0.1717 - val_loss: 0.0677 - val_mae: 0.1880
# Epoch 133/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0579 - mae: 0.1713 - val_loss: 0.0674 - val_mae: 0.1877
# Epoch 134/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0577 - mae: 0.1709 - val_loss: 0.0671 - val_mae: 0.1873
# Epoch 135/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0574 - mae: 0.1706 - val_loss: 0.0668 - val_mae: 0.1870
# Epoch 136/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0572 - mae: 0.1702 - val_loss: 0.0666 - val_mae: 0.1866
# Epoch 137/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0570 - mae: 0.1699 - val_loss: 0.0663 - val_mae: 0.1863
# Epoch 138/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0567 - mae: 0.1694 - val_loss: 0.0660 - val_mae: 0.1859
# Epoch 139/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0565 - mae: 0.1691 - val_loss: 0.0657 - val_mae: 0.1856
# Epoch 140/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0562 - mae: 0.1686 - val_loss: 0.0655 - val_mae: 0.1853
# Epoch 141/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0560 - mae: 0.1684 - val_loss: 0.0652 - val_mae: 0.1849
# Epoch 142/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0558 - mae: 0.1680 - val_loss: 0.0649 - val_mae: 0.1846
# Epoch 143/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0555 - mae: 0.1677 - val_loss: 0.0646 - val_mae: 0.1842
# Epoch 144/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0553 - mae: 0.1672 - val_loss: 0.0643 - val_mae: 0.1839
# Epoch 145/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0551 - mae: 0.1669 - val_loss: 0.0641 - val_mae: 0.1835
# Epoch 146/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0548 - mae: 0.1665 - val_loss: 0.0638 - val_mae: 0.1832
# Epoch 147/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0546 - mae: 0.1662 - val_loss: 0.0635 - val_mae: 0.1828
# Epoch 148/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0544 - mae: 0.1658 - val_loss: 0.0632 - val_mae: 0.1825
# Epoch 149/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0541 - mae: 0.1655 - val_loss: 0.0630 - val_mae: 0.1821
# Epoch 150/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0539 - mae: 0.1651 - val_loss: 0.0627 - val_mae: 0.1818
# Epoch 151/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0537 - mae: 0.1648 - val_loss: 0.0624 - val_mae: 0.1814
# Epoch 152/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0534 - mae: 0.1644 - val_loss: 0.0621 - val_mae: 0.1812
# Epoch 153/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0532 - mae: 0.1641 - val_loss: 0.0619 - val_mae: 0.1808
# Epoch 154/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0530 - mae: 0.1637 - val_loss: 0.0616 - val_mae: 0.1805
# Epoch 155/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0527 - mae: 0.1633 - val_loss: 0.0613 - val_mae: 0.1801
# Epoch 156/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0525 - mae: 0.1629 - val_loss: 0.0610 - val_mae: 0.1797
# Epoch 157/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0523 - mae: 0.1626 - val_loss: 0.0607 - val_mae: 0.1794
# Epoch 158/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0520 - mae: 0.1622 - val_loss: 0.0605 - val_mae: 0.1791
# Epoch 159/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0518 - mae: 0.1619 - val_loss: 0.0602 - val_mae: 0.1788
# Epoch 160/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0516 - mae: 0.1616 - val_loss: 0.0599 - val_mae: 0.1784
# Epoch 161/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0513 - mae: 0.1612 - val_loss: 0.0596 - val_mae: 0.1780
# Epoch 162/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0511 - mae: 0.1608 - val_loss: 0.0593 - val_mae: 0.1776
# Epoch 163/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0509 - mae: 0.1605 - val_loss: 0.0590 - val_mae: 0.1772
# Epoch 164/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0506 - mae: 0.1602 - val_loss: 0.0588 - val_mae: 0.1768
# Epoch 165/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0504 - mae: 0.1598 - val_loss: 0.0585 - val_mae: 0.1764
# Epoch 166/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0501 - mae: 0.1595 - val_loss: 0.0582 - val_mae: 0.1760
# Epoch 167/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0499 - mae: 0.1591 - val_loss: 0.0579 - val_mae: 0.1756
# Epoch 168/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0497 - mae: 0.1588 - val_loss: 0.0576 - val_mae: 0.1752
# Epoch 169/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0494 - mae: 0.1585 - val_loss: 0.0573 - val_mae: 0.1748
# Epoch 170/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0492 - mae: 0.1581 - val_loss: 0.0570 - val_mae: 0.1744
# Epoch 171/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0490 - mae: 0.1577 - val_loss: 0.0567 - val_mae: 0.1739
# Epoch 172/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0487 - mae: 0.1574 - val_loss: 0.0564 - val_mae: 0.1735
# Epoch 173/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0485 - mae: 0.1570 - val_loss: 0.0561 - val_mae: 0.1731
# Epoch 174/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0482 - mae: 0.1566 - val_loss: 0.0558 - val_mae: 0.1727
# Epoch 175/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0480 - mae: 0.1563 - val_loss: 0.0555 - val_mae: 0.1723
# Epoch 176/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0477 - mae: 0.1559 - val_loss: 0.0553 - val_mae: 0.1719
# Epoch 177/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0475 - mae: 0.1555 - val_loss: 0.0550 - val_mae: 0.1715
# Epoch 178/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0473 - mae: 0.1552 - val_loss: 0.0547 - val_mae: 0.1711
# Epoch 179/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0470 - mae: 0.1548 - val_loss: 0.0544 - val_mae: 0.1706
# Epoch 180/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0468 - mae: 0.1545 - val_loss: 0.0541 - val_mae: 0.1703
# Epoch 181/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0465 - mae: 0.1541 - val_loss: 0.0538 - val_mae: 0.1699
# Epoch 182/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0463 - mae: 0.1538 - val_loss: 0.0535 - val_mae: 0.1695
# Epoch 183/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0461 - mae: 0.1534 - val_loss: 0.0532 - val_mae: 0.1691
# Epoch 184/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0458 - mae: 0.1531 - val_loss: 0.0528 - val_mae: 0.1687
# Epoch 185/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0456 - mae: 0.1527 - val_loss: 0.0525 - val_mae: 0.1682
# Epoch 186/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0453 - mae: 0.1523 - val_loss: 0.0522 - val_mae: 0.1678
# Epoch 187/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0451 - mae: 0.1519 - val_loss: 0.0519 - val_mae: 0.1673
# Epoch 188/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0448 - mae: 0.1515 - val_loss: 0.0516 - val_mae: 0.1669
# Epoch 189/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0446 - mae: 0.1511 - val_loss: 0.0513 - val_mae: 0.1665
# Epoch 190/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0443 - mae: 0.1507 - val_loss: 0.0510 - val_mae: 0.1661
# Epoch 191/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0441 - mae: 0.1504 - val_loss: 0.0507 - val_mae: 0.1657
# Epoch 192/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0438 - mae: 0.1500 - val_loss: 0.0504 - val_mae: 0.1653
# Epoch 193/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0436 - mae: 0.1496 - val_loss: 0.0500 - val_mae: 0.1649
# Epoch 194/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0433 - mae: 0.1492 - val_loss: 0.0497 - val_mae: 0.1644
# Epoch 195/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0430 - mae: 0.1488 - val_loss: 0.0494 - val_mae: 0.1640
# Epoch 196/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0428 - mae: 0.1484 - val_loss: 0.0491 - val_mae: 0.1636
# Epoch 197/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0425 - mae: 0.1480 - val_loss: 0.0488 - val_mae: 0.1632
# Epoch 198/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0423 - mae: 0.1476 - val_loss: 0.0485 - val_mae: 0.1627
# Epoch 199/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0420 - mae: 0.1472 - val_loss: 0.0481 - val_mae: 0.1621
# Epoch 200/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0418 - mae: 0.1468 - val_loss: 0.0478 - val_mae: 0.1617
# Epoch 201/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0415 - mae: 0.1464 - val_loss: 0.0475 - val_mae: 0.1612
# Epoch 202/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0412 - mae: 0.1460 - val_loss: 0.0472 - val_mae: 0.1608
# Epoch 203/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0410 - mae: 0.1456 - val_loss: 0.0469 - val_mae: 0.1603
# Epoch 204/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0407 - mae: 0.1452 - val_loss: 0.0465 - val_mae: 0.1599
# Epoch 205/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0405 - mae: 0.1448 - val_loss: 0.0462 - val_mae: 0.1595
# Epoch 206/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0402 - mae: 0.1444 - val_loss: 0.0459 - val_mae: 0.1590
# Epoch 207/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0399 - mae: 0.1440 - val_loss: 0.0456 - val_mae: 0.1584
# Epoch 208/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0397 - mae: 0.1435 - val_loss: 0.0452 - val_mae: 0.1579
# Epoch 209/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0394 - mae: 0.1431 - val_loss: 0.0449 - val_mae: 0.1574
# Epoch 210/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0392 - mae: 0.1427 - val_loss: 0.0446 - val_mae: 0.1569
# Epoch 211/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0389 - mae: 0.1422 - val_loss: 0.0443 - val_mae: 0.1564
# Epoch 212/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0386 - mae: 0.1418 - val_loss: 0.0439 - val_mae: 0.1560
# Epoch 213/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0384 - mae: 0.1415 - val_loss: 0.0436 - val_mae: 0.1555
# Epoch 214/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0381 - mae: 0.1410 - val_loss: 0.0433 - val_mae: 0.1550
# Epoch 215/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0379 - mae: 0.1405 - val_loss: 0.0430 - val_mae: 0.1544
# Epoch 216/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0376 - mae: 0.1401 - val_loss: 0.0426 - val_mae: 0.1539
# Epoch 217/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0373 - mae: 0.1396 - val_loss: 0.0423 - val_mae: 0.1534
# Epoch 218/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0371 - mae: 0.1392 - val_loss: 0.0420 - val_mae: 0.1529
# Epoch 219/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0368 - mae: 0.1387 - val_loss: 0.0416 - val_mae: 0.1524
# Epoch 220/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0366 - mae: 0.1383 - val_loss: 0.0413 - val_mae: 0.1518
# Epoch 221/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0363 - mae: 0.1378 - val_loss: 0.0410 - val_mae: 0.1513
# Epoch 222/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0360 - mae: 0.1373 - val_loss: 0.0407 - val_mae: 0.1508
# Epoch 223/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0358 - mae: 0.1369 - val_loss: 0.0403 - val_mae: 0.1502
# Epoch 224/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0355 - mae: 0.1364 - val_loss: 0.0400 - val_mae: 0.1496
# Epoch 225/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0353 - mae: 0.1360 - val_loss: 0.0397 - val_mae: 0.1490
# Epoch 226/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0350 - mae: 0.1355 - val_loss: 0.0393 - val_mae: 0.1485
# Epoch 227/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0348 - mae: 0.1351 - val_loss: 0.0390 - val_mae: 0.1479
# Epoch 228/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0345 - mae: 0.1347 - val_loss: 0.0387 - val_mae: 0.1474
# Epoch 229/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0342 - mae: 0.1342 - val_loss: 0.0384 - val_mae: 0.1468
# Epoch 230/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0340 - mae: 0.1338 - val_loss: 0.0380 - val_mae: 0.1463
# Epoch 231/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0337 - mae: 0.1333 - val_loss: 0.0377 - val_mae: 0.1457
# Epoch 232/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0334 - mae: 0.1329 - val_loss: 0.0374 - val_mae: 0.1451
# Epoch 233/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0332 - mae: 0.1324 - val_loss: 0.0370 - val_mae: 0.1446
# Epoch 234/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0329 - mae: 0.1320 - val_loss: 0.0367 - val_mae: 0.1442
# Epoch 235/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0327 - mae: 0.1315 - val_loss: 0.0364 - val_mae: 0.1436
# Epoch 236/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0324 - mae: 0.1310 - val_loss: 0.0361 - val_mae: 0.1430
# Epoch 237/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0321 - mae: 0.1306 - val_loss: 0.0357 - val_mae: 0.1425
# Epoch 238/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0319 - mae: 0.1301 - val_loss: 0.0354 - val_mae: 0.1420
# Epoch 239/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0316 - mae: 0.1296 - val_loss: 0.0351 - val_mae: 0.1414
# Epoch 240/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0314 - mae: 0.1291 - val_loss: 0.0348 - val_mae: 0.1409
# Epoch 241/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0311 - mae: 0.1286 - val_loss: 0.0344 - val_mae: 0.1404
# Epoch 242/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0308 - mae: 0.1282 - val_loss: 0.0341 - val_mae: 0.1399
# Epoch 243/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0306 - mae: 0.1277 - val_loss: 0.0338 - val_mae: 0.1394
# Epoch 244/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0303 - mae: 0.1273 - val_loss: 0.0335 - val_mae: 0.1388
# Epoch 245/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0301 - mae: 0.1268 - val_loss: 0.0332 - val_mae: 0.1383
# Epoch 246/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0298 - mae: 0.1263 - val_loss: 0.0329 - val_mae: 0.1378
# Epoch 247/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0296 - mae: 0.1259 - val_loss: 0.0326 - val_mae: 0.1373
# Epoch 248/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0293 - mae: 0.1254 - val_loss: 0.0323 - val_mae: 0.1368
# Epoch 249/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0291 - mae: 0.1250 - val_loss: 0.0320 - val_mae: 0.1363
# Epoch 250/250
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0288 - mae: 0.1245 - val_loss: 0.0317 - val_mae: 0.1358
# models/model.keras

# %% [markdown]
# ### 3. Plot Metrics
# Each training epoch, the model prints out its loss and mean absolute error for training and validation. You can read this in the output above (note that your exact numbers may differ):
#
# ```
# Epoch 500/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0121 - mae: 0.0882 - val_loss: 0.0115 - val_mae: 0.0865
# ```
#
# You can see that we've already got a huge improvement - validation loss has dropped from 0.15 to 0.01, and validation MAE has dropped from 0.33 to 0.08.
#
# The following cell will print the same graphs we used to evaluate our original model, but showing our new training history:

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_loss) + 1)

# Exclude the first few epochs so the graph is easier to read
SKIP = 400

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)

plt.plot(epochs[SKIP:], train_loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
train_mae = history.history['mae']
val_mae = history.history['val_mae']

plt.plot(epochs[SKIP:], train_mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.tight_layout()

# %% [markdown]
# Great results! From these graphs, we can see several exciting things:
#
# *   The overall loss and MAE are much better than our previous network
# *   Metrics are better for validation than training, which means the network is not overfitting
#
# The reason the metrics for validation are better than those for training is that validation metrics are calculated at the end of each epoch, while training metrics are calculated throughout the epoch, so validation happens on a model that has been trained slightly longer.
#
# This all means our network seems to be performing well! To confirm, let's check its predictions against the test dataset we set aside earlier:

# %%
# Calculate and print the loss on our test dataset
test_loss, test_mae = model.evaluate(x_test, y_test)

# Make predictions based on our test dataset
y_test_pred = model.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual values')
plt.plot(x_test, y_test_pred, 'r.', label='TF predicted')
plt.legend()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0304 - mae: 0.1316
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# Much better! The evaluation metrics we printed show that the model has a low loss and MAE on the test data, and the predictions line up visually with our data fairly well.
#
# The model isn't perfect; its predictions don't form a smooth sine curve. For instance, the line is almost straight when `x` is between 4.2 and 5.2. If we wanted to go further, we could try further increasing the capacity of the model, perhaps using some techniques to defend from overfitting.
#
# However, an important part of machine learning is *knowing when to stop*. This model is good enough for our use case - which is to make some LEDs blink in a pleasing pattern.
#
# ## Generate a TensorFlow Lite Model

# %% [markdown]
# ### 1. Generate Models with or without Quantization
# We now have an acceptably accurate model. We'll use the [TensorFlow Lite Converter](https://www.tensorflow.org/lite/convert) to convert the model into a special, space-efficient format for use on memory-constrained devices.
#
# Since this model is going to be deployed on a microcontroller, we want it to be as tiny as possible! One technique for reducing the size of a model is called [quantization](https://www.tensorflow.org/lite/performance/post_training_quantization). It reduces the precision of the model's weights, and possibly the activations (output of each layer) as well, which saves memory, often without much impact on accuracy. Quantized models also run faster, since the calculations required are simpler.
#
# In the following cell, we'll convert the model twice: once with quantization, once without.

# %%
model = keras.models.load_model("models/model.keras")

# %%
# Convert the model to the TensorFlow Lite format without quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
model_no_quant_tflite = converter.convert()

# Save the model to disk
open(MODEL_NO_QUANT_TFLITE, "wb").write(model_no_quant_tflite)
# Out:
# Saved artifact at '/tmp/tmppq9cwkjh'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   136338521848528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136338602044368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136338602039376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136338605096208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136338605095824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136338602043984: TensorSpec(shape=(), dtype=tf.resource, name=None)
# 3160

# %%
# Convert the model to the TensorFlow Lite format with quantization
def representative_dataset():
  for i in range(500):
    yield([x_train[i].reshape(1, 1)])

# Set the optimization flag.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Enforce integer only quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
# Provide a representative dataset to ensure we quantize correctly.
converter.representative_dataset = representative_dataset
model_tflite = converter.convert()

# Save the model to disk
open(MODEL_TFLITE, "wb").write(model_tflite)
# Out:
# Saved artifact at '/tmp/tmphzqym7_k'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   136338521848528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136338602044368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136338602039376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136338605096208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136338605095824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136338602043984: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 3792

# %% [markdown]
# ### 2. Compare Model Performance
#
# To prove these models are accurate even after conversion and quantization, we'll compare their predictions and loss on our test dataset.
#
# **Helper functions**
#
# We define the `predict` (for predictions) and `evaluate` (for loss) functions for TFLite models. *Note: These are already included in a TF model, but not in  a TFLite model.*

# %%
def predict_tflite(tflite_model, x_test):
  # Prepare the test data
  x_test_ = x_test.copy()
  x_test_ = x_test_.reshape((x_test.size, 1))
  x_test_ = x_test_.astype(np.float32)

  # Initialize the TFLite interpreter (FIXED: removed deprecated parameter)
  interpreter = tf.lite.Interpreter(model_content=tflite_model)
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  # If required, quantize the input layer (from float to integer)
  input_scale, input_zero_point = input_details["quantization"]
  if (input_scale, input_zero_point) != (0.0, 0):
    x_test_ = x_test_ / input_scale + input_zero_point
    x_test_ = x_test_.astype(input_details["dtype"])

  # Invoke the interpreter
  y_pred = np.empty(x_test_.size, dtype=output_details["dtype"])
  for i in range(len(x_test_)):
    interpreter.set_tensor(input_details["index"], [x_test_[i]])
    interpreter.invoke()
    # FIXED: properly extract scalar from array
    y_pred[i] = interpreter.get_tensor(output_details["index"]).item()

  # If required, dequantized the output layer (from integer to float)
  output_scale, output_zero_point = output_details["quantization"]
  if (output_scale, output_zero_point) != (0.0, 0):
    y_pred = y_pred.astype(np.float32)
    y_pred = (y_pred - output_zero_point) * output_scale

  return y_pred

def evaluate_tflite(tflite_model, x_test, y_true):
  global model
  y_pred = predict_tflite(tflite_model, x_test)
  loss_function = tf.keras.losses.get(model.loss)
  loss = loss_function(y_true, y_pred).numpy()
  return loss

# %% [markdown]
# **1. Predictions**

# %%
# Calculate predictions
y_test_pred_tf = model.predict(x_test)
y_test_pred_no_quant_tflite = predict_tflite(model_no_quant_tflite, x_test)
y_test_pred_tflite = predict_tflite(model_tflite, x_test)
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bffc81f5120> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %% [markdown]
# **2. Loss (MSE/Mean Squared Error)**

# %%
# Calculate loss
loss_tf, _ = model.evaluate(x_test, y_test, verbose=0)
loss_no_quant_tflite = evaluate_tflite(model_no_quant_tflite, x_test, y_test)
loss_tflite = evaluate_tflite(model_tflite, x_test, y_test)

# %%
# Compare loss
df = pd.DataFrame.from_records(
    [["TensorFlow", loss_tf],
     ["TensorFlow Lite", loss_no_quant_tflite],
     ["TensorFlow Lite Quantized", loss_tflite]],
     columns = ["Model", "Loss/MSE"], index="Model").round(4)
df
# Out:
#                            Loss/MSE
# Model
# TensorFlow                   0.0299
# TensorFlow Lite              0.0299
# TensorFlow Lite Quantized    0.0297

# %% [markdown]
# **3. Size**

# %%
# Calculate size
size_tf = os.path.getsize(MODEL_TF)
size_no_quant_tflite = os.path.getsize(MODEL_NO_QUANT_TFLITE)
size_tflite = os.path.getsize(MODEL_TFLITE)

# %%
# Compare size
pd.DataFrame.from_records(
    [["TensorFlow", f"{size_tf} bytes", ""],
     ["TensorFlow Lite", f"{size_no_quant_tflite} bytes ", f"(reduced by {size_tf - size_no_quant_tflite} bytes)"],
     ["TensorFlow Lite Quantized", f"{size_tflite} bytes", f"(reduced by {size_no_quant_tflite - size_tflite} bytes)"]],
     columns = ["Model", "Size", ""], index="Model")
# Out:
#                                   Size
# Model
# TensorFlow                 29256 bytes
# TensorFlow Lite            3160 bytes   (reduced by 26096 bytes)
# TensorFlow Lite Quantized   3792 bytes   (reduced by -632 bytes)

# %% [markdown]
# **Summary**

# %% [markdown]
# We can see from the predictions (graph) and loss (table) that the original TF model, the TFLite model, and the quantized TFLite model are all close enough to be indistinguishable - even though they differ in size (table). This implies that the quantized (smallest) model is ready to use!
#
# *Note: The quantized (integer) TFLite model is just 300 bytes smaller than the original (float) TFLite model - a tiny reduction in size! This is because the model is already so small that quantization has little effect. Complex models with more weights, can have upto a 4x reduction in size!*

# %% [markdown]
# ## Generate a TensorFlow Lite for Microcontrollers Model
# Convert the TensorFlow Lite quantized model into a C source file that can be loaded by TensorFlow Lite for Microcontrollers.

# %%
# Install xxd if it is not available
# !apt-get update && apt-get -qq install xxd
# Convert to a C source file, i.e, a TensorFlow Lite for Microcontrollers model
# !xxd -i {MODEL_TFLITE} > {MODEL_TFLITE_MICRO}
# Update variable names
REPLACE_TEXT = MODEL_TFLITE.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'/g_model/g' {MODEL_TFLITE_MICRO}
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,153 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,836 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,008 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,592 kB]
# Get:17 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,222 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,491 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,286 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,870 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,535 kB]
# Fetched 37.5 MB in 5s (7,990 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %% [markdown]
# ## Deploy to a Microcontroller
#
# Follow the instructions in the [hello_world](https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world) README.md for [TensorFlow Lite for MicroControllers](https://www.tensorflow.org/lite/microcontrollers/overview) to deploy this model on a specific microcontroller.
#
# **Reference Model:** If you have not modified this notebook, you can follow the instructions as is, to deploy the model. Refer to the [`hello_world/train/models`](https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world/train/models) directory to access the models generated in this notebook.
#
# **New Model:** If you have generated a new model, then update the values assigned to the variables defined in [`hello_world/model.cc`](https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world/model.cc) with values displayed after running the following cell.

# %%
# Print the C source file
# !cat {MODEL_TFLITE_MICRO}
# Out:
# unsigned char g_model[] = {
#   0x20, 0x00, 0x00, 0x00, 0x54, 0x46, 0x4c, 0x33, 0x00, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x20, 0x00, 0x1c, 0x00, 0x18, 0x00, 0x14, 0x00, 0x10, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x04, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x1c, 0x00, 0x00, 0x00, 0x8c, 0x00, 0x00, 0x00, 0x0c, 0x01, 0x00, 0x00,
#   0x00, 0x04, 0x00, 0x00, 0x10, 0x04, 0x00, 0x00, 0x44, 0x0e, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0xae, 0xfb, 0xff, 0xff, 0x0c, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00,
#   0x3c, 0x00, 0x00, 0x00, 0x0f, 0x00, 0x00, 0x00, 0x73, 0x65, 0x72, 0x76,
#   0x69, 0x6e, 0x67, 0x5f, 0x64, 0x65, 0x66, 0x61, 0x75, 0x6c, 0x74, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x68, 0xff, 0xff, 0xff,
#   0x0b, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x6f, 0x75, 0x74, 0x70, 0x75, 0x74, 0x5f, 0x30, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x86, 0xfc, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x0d, 0x00, 0x00, 0x00, 0x69, 0x6e, 0x70, 0x75,
#   0x74, 0x5f, 0x6c, 0x61, 0x79, 0x65, 0x72, 0x5f, 0x31, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x5c, 0x00, 0x00, 0x00, 0x2c, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xb8, 0xff, 0xff, 0xff, 0x0f, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x13, 0x00, 0x00, 0x00, 0x43, 0x4f, 0x4e, 0x56,
#   0x45, 0x52, 0x53, 0x49, 0x4f, 0x4e, 0x5f, 0x4d, 0x45, 0x54, 0x41, 0x44,
#   0x41, 0x54, 0x41, 0x00, 0xdc, 0xff, 0xff, 0xff, 0x0e, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x13, 0x00, 0x00, 0x00, 0x6d, 0x69, 0x6e, 0x5f,
#   0x72, 0x75, 0x6e, 0x74, 0x69, 0x6d, 0x65, 0x5f, 0x76, 0x65, 0x72, 0x73,
#   0x69, 0x6f, 0x6e, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x0d, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x13, 0x00, 0x00, 0x00, 0x6d, 0x69, 0x6e, 0x5f, 0x72, 0x75, 0x6e, 0x74,
#   0x69, 0x6d, 0x65, 0x5f, 0x76, 0x65, 0x72, 0x73, 0x69, 0x6f, 0x6e, 0x00,
#   0x10, 0x00, 0x00, 0x00, 
x12, 0x00, 0x00, 0x00, 0x74, 0x66, 0x6c, 0x2e, 0x70, 0x73, 0x65, 0x75,
#   0x64, 0x6f, 0x5f, 0x71, 0x63, 0x6f, 0x6e, 0x73, 0x74, 0x32, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x9a, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x01, 0x14, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0x40, 0x00, 0x00, 0x00,
#   0x84, 0xff, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x41, 0x92, 0x1c, 0x3c,
#   0x12, 0x00, 0x00, 0x00, 0x74, 0x66, 0x6c, 0x2e, 0x70, 0x73, 0x65, 0x75,
#   0x64, 0x6f, 0x5f, 0x71, 0x63, 0x6f, 0x6e, 0x73, 0x74, 0x31, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x16, 0x00, 0x1c, 0x00, 0x18, 0x00, 0x17, 0x00, 0x10, 0x00,
#   0x0c, 0x00, 0x08, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x07, 0x00,
#   0x16, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x20, 0x00, 0x00, 0x00,
#   0x40, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x02,
#   0x4c, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x04, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0xb3, 0x34, 0x7c, 0x38, 0x11, 0x00, 0x00, 0x00, 0x74, 0x66, 0x6c, 0x2e,
#   0x70, 0x73, 0x65, 0x75, 0x64, 0x6f, 0x5f, 0x71, 0x63, 0x6f, 0x6e, 0x73,
#   0x74, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x16, 0x00, 0x1c, 0x00, 0x18, 0x00, 0x00, 0x00, 0x14, 0x00,
#   0x10, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x00, 0x00, 0x08, 0x00, 0x07, 0x00,
#   0x16, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x14, 0x00, 0x00, 0x00,
#   0x20, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x3c, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff,
#   0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x04, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x1f, 0x00, 0x00, 0x00, 0x73, 0x65, 0x72, 0x76, 0x69, 0x6e, 0x67, 0x5f,
#   0x64, 0x65, 0x66, 0x61, 0x75, 0x6c, 0x74, 0x5f, 0x69, 0x6e, 0x70, 0x75,
#   0x74, 0x5f, 0x6c, 0x61, 0x79, 0x65, 0x72, 0x5f, 0x31, 0x3a, 0x30, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xf0, 0xff, 0xff, 0xff, 0x06, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x06, 0x0c, 0x00, 0x10, 0x00,
#   0x0f, 0x00, 0x00, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x09, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09,
#   0x0c, 0x00, 0x0c, 0x00, 0x0b, 0x00, 0x00, 0x00, 0x00, 0x00, 0x04, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x72, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x72
# };
# unsigned int g_model_len = 3792;
